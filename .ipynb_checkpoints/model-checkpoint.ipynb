# %%
from sklearn.preprocessing import LabelEncoder
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
# Out:
# /Users/yaswanthkommineni/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
TRAIN_DATA = "Dataset/train"
TEST_DATA = "Dataset/test"

# %%
def create_dataframe(directory):
    image_paths = []
    labels = []
    for label_entry in tqdm(os.scandir(directory), desc="Processing Labels"):
        if label_entry.is_dir():
            label = label_entry.name
            for image_entry in os.scandir(label_entry.path):
                if image_entry.is_file():
                    image_paths.append(image_entry.path)
                    labels.append(label)
    return pd.DataFrame({"Image_Path": image_paths, "Label": labels})

# %%
# Create the DataFrame for training data
train = create_dataframe(TRAIN_DATA)

# Display the first few rows of the DataFrame
print(train)
print(train['Image_Path'])
print(train['Label'].value_counts())
# Out:
# Processing Labels: 7it [00:00, 104.89it/s]
#                                         Image_Path    Label
# 0        Dataset/train/happy/Training_50449107.jpg    happy
# 1        Dataset/train/happy/Training_70433018.jpg    happy
# 2        Dataset/train/happy/Training_85610005.jpg    happy
# 3         Dataset/train/happy/Training_4460748.jpg    happy
# 4         Dataset/train/happy/Training_6312930.jpg    happy
# ...                                            ...      ...
# 28704  Dataset/train/disgust/Training_94788538.jpg  disgust
# 28705  Dataset/train/disgust/Training_81049148.jpg  disgust
# 28706  Dataset/train/disgust/Training_28365203.jpg  disgust
# 28707  Dataset/train/disgust/Training_39197750.jpg  disgust
# 28708  Dataset/train/disgust/Training_12525818.jpg  disgust
#
# [28709 rows x 2 columns]
# 0          Dataset/train/happy/Training_50449107.jpg
# 1          Dataset/train/happy/Training_70433018.jpg
# 2          Dataset/train/happy/Training_85610005.jpg
# 3           Dataset/train/happy/Training_4460748.jpg
# 4           Dataset/train/happy/Training_6312930.jpg
#                             ...
# 28704    Dataset/train/disgust/Training_94788538.jpg
# 28705    Dataset/train/disgust/Training_81049148.jpg
# 28706    Dataset/train/disgust/Training_28365203.jpg
# 28707    Dataset/train/disgust/Training_39197750.jpg
# 28708    Dataset/train/disgust/Training_12525818.jpg
# Name: Image_Path, Length: 28709, dtype: object
# Label
# happy       7215
# neutral     4965
# sad         4830
# fear        4097
# angry       3995
# surprise    3171
# disgust      436
# Name: count, dtype: int64

# %%
# Create the DataFrame for test data
test = create_dataframe(TEST_DATA)

# Display the first few rows of the DataFrame
print(test)
print(test['Image_Path'])
print(test['Label'].value_counts())
# Out:
# Processing Labels: 7it [00:00, 355.08it/s]
#                                          Image_Path    Label
# 0       Dataset/test/happy/PrivateTest_45699463.jpg    happy
# 1       Dataset/test/happy/PrivateTest_61855708.jpg    happy
# 2        Dataset/test/happy/PublicTest_53681781.jpg    happy
# 3       Dataset/test/happy/PrivateTest_52109800.jpg    happy
# 4        Dataset/test/happy/PublicTest_41104919.jpg    happy
# ...                                             ...      ...
# 7173  Dataset/test/disgust/PrivateTest_79683471.jpg  disgust
# 7174  Dataset/test/disgust/PrivateTest_34013087.jpg  disgust
# 7175   Dataset/test/disgust/PublicTest_67559665.jpg  disgust
# 7176  Dataset/test/disgust/PrivateTest_89077668.jpg  disgust
# 7177  Dataset/test/disgust/PrivateTest_53395751.jpg  disgust
#
# [7178 rows x 2 columns]
# 0         Dataset/test/happy/PrivateTest_45699463.jpg
# 1         Dataset/test/happy/PrivateTest_61855708.jpg
# 2          Dataset/test/happy/PublicTest_53681781.jpg
# 3         Dataset/test/happy/PrivateTest_52109800.jpg
# 4          Dataset/test/happy/PublicTest_41104919.jpg
#                             ...
# 7173    Dataset/test/disgust/PrivateTest_79683471.jpg
# 7174    Dataset/test/disgust/PrivateTest_34013087.jpg
# 7175     Dataset/test/disgust/PublicTest_67559665.jpg
# 7176    Dataset/test/disgust/PrivateTest_89077668.jpg
# 7177    Dataset/test/disgust/PrivateTest_53395751.jpg
# Name: Image_Path, Length: 7178, dtype: object
# Label
# happy       1774
# sad         1247
# neutral     1233
# fear        1024
# angry        958
# surprise     831
# disgust      111
# Name: count, dtype: int64

# %%
def extract_features(images, target_size=(48, 48)):
    features = []
    for image in tqdm(images):
        img = load_img(image, target_size=target_size, color_mode='grayscale')
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features), target_size[0], target_size[1], 1)
    return features

# %%
train_features = extract_features(train['Image_Path'])
# Out:
# 100%|███████████████████████████████████| 28709/28709 [00:04<00:00, 5979.84it/s]

# %%
test_features = extract_features(test['Image_Path'])
# Out:
# 100%|█████████████████████████████████████| 7178/7178 [00:01<00:00, 6730.41it/s]

# %%
x_train = train_features/250.0  # Scale pixle values to [0, 1]
x_test = test_features/250.0

# %%
# Assuming train is your DataFrame containing image paths and labels
le = LabelEncoder()
le.fit(train['Label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['Label'])
y_test = le.transform(test['Label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
model = Sequential()

# Define the input layer separately
model.add(Input(shape=(48, 48, 1)))

# Convolutional layers
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

# Flatten the feature maps into a 1D vector
model.add(Flatten())

# Fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

# Output layer with 7 neurons (one for each class), using softmax activation
model.add(Dense(7, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x= x_train,y = y_train, batch_size = 128, epochs = 100, validation_data = (x_test,y_test))
# Out:
# Epoch 1/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 699ms/step - accuracy: 0.2370 - loss: 1.8333 - val_accuracy: 0.2471 - val_loss: 1.8060
# Epoch 2/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 159s 705ms/step - accuracy: 0.2522 - loss: 1.7969 - val_accuracy: 0.3082 - val_loss: 1.6937
# Epoch 3/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 703ms/step - accuracy: 0.3110 - loss: 1.6952 - val_accuracy: 0.4087 - val_loss: 1.5346
# Epoch 4/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 160s 712ms/step - accuracy: 0.3836 - loss: 1.5607 - val_accuracy: 0.4636 - val_loss: 1.3961
# Epoch 5/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 161s 717ms/step - accuracy: 0.4270 - loss: 1.4638 - val_accuracy: 0.4745 - val_loss: 1.3640
# Epoch 6/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 165s 734ms/step - accuracy: 0.4587 - loss: 1.4057 - val_accuracy: 0.5031 - val_loss: 1.2898
# Epoch 7/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 160s 710ms/step - accuracy: 0.4718 - loss: 1.3795 - val_accuracy: 0.5113 - val_loss: 1.2703
# Epoch 8/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 162s 719ms/step - accuracy: 0.4898 - loss: 1.3314 - val_accuracy: 0.5287 - val_loss: 1.2365
# Epoch 9/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 162s 719ms/step - accuracy: 0.4952 - loss: 1.3050 - val_accuracy: 0.5375 - val_loss: 1.2059
# Epoch 10/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 161s 717ms/step - accuracy: 0.5023 - loss: 1.2948 - val_accuracy: 0.5450 - val_loss: 1.1840
# Epoch 11/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 161s 716ms/step - accuracy: 0.5140 - loss: 1.2733 - val_accuracy: 0.5471 - val_loss: 1.1837
# Epoch 12/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 161s 718ms/step - accuracy: 0.5196 - loss: 1.2562 - val_accuracy: 0.5563 - val_loss: 1.1643
# Epoch 13/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 163s 723ms/step - accuracy: 0.5246 - loss: 1.2463 - val_accuracy: 0.5575 - val_loss: 1.1603
# Epoch 14/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 163s 726ms/step - accuracy: 0.5363 - loss: 1.2206 - val_accuracy: 0.5667 - val_loss: 1.1489
# Epoch 15/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 163s 725ms/step - accuracy: 0.5421 - loss: 1.1944 - val_accuracy: 0.5649 - val_loss: 1.1411
# Epoch 16/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 162s 719ms/step - accuracy: 0.5448 - loss: 1.1958 - val_accuracy: 0.5669 - val_loss: 1.1222
# Epoch 17/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 162s 721ms/step - accuracy: 0.5517 - loss: 1.1785 - val_accuracy: 0.5780 - val_loss: 1.1155
# Epoch 18/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 746ms/step - accuracy: 0.5553 - loss: 1.1669 - val_accuracy: 0.5754 - val_loss: 1.1048
# Epoch 19/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 747ms/step - accuracy: 0.5621 - loss: 1.1490 - val_accuracy: 0.5795 - val_loss: 1.0952
# Epoch 20/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 745ms/step - accuracy: 0.5650 - loss: 1.1511 - val_accuracy: 0.5812 - val_loss: 1.0873
# Epoch 21/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 747ms/step - accuracy: 0.5670 - loss: 1.1383 - val_accuracy: 0.5846 - val_loss: 1.0922
# Epoch 22/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 751ms/step - accuracy: 0.5719 - loss: 1.1361 - val_accuracy: 0.5758 - val_loss: 1.0974
# Epoch 23/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 748ms/step - accuracy: 0.5855 - loss: 1.1094 - val_accuracy: 0.5858 - val_loss: 1.0907
# Epoch 24/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 746ms/step - accuracy: 0.5824 - loss: 1.1067 - val_accuracy: 0.5858 - val_loss: 1.0816
# Epoch 25/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 748ms/step - accuracy: 0.5866 - loss: 1.0931 - val_accuracy: 0.5919 - val_loss: 1.0762
# Epoch 26/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 751ms/step - accuracy: 0.5845 - loss: 1.0951 - val_accuracy: 0.5829 - val_loss: 1.0778
# Epoch 27/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 754ms/step - accuracy: 0.5914 - loss: 1.0795 - val_accuracy: 0.5932 - val_loss: 1.0716
# Epoch 28/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 760ms/step - accuracy: 0.6010 - loss: 1.0706 - val_accuracy: 0.5931 - val_loss: 1.0624
# Epoch 29/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 173s 767ms/step - accuracy: 0.5994 - loss: 1.0687 - val_accuracy: 0.5928 - val_loss: 1.0793
# Epoch 30/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 174s 774ms/step - accuracy: 0.6009 - loss: 1.0454 - val_accuracy: 0.6018 - val_loss: 1.0562
# Epoch 31/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 175s 778ms/step - accuracy: 0.6048 - loss: 1.0445 - val_accuracy: 0.5985 - val_loss: 1.0613
# Epoch 32/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 175s 778ms/step - accuracy: 0.6061 - loss: 1.0460 - val_accuracy: 0.5975 - val_loss: 1.0605
# Epoch 33/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 172s 766ms/step - accuracy: 0.6069 - loss: 1.0528 - val_accuracy: 0.6009 - val_loss: 1.0504
# Epoch 34/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 163s 727ms/step - accuracy: 0.6130 - loss: 1.0267 - val_accuracy: 0.5984 - val_loss: 1.0521
# Epoch 35/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 165s 734ms/step - accuracy: 0.6142 - loss: 1.0257 - val_accuracy: 0.5989 - val_loss: 1.0616
# Epoch 36/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 166s 740ms/step - accuracy: 0.6160 - loss: 1.0252 - val_accuracy: 0.6011 - val_loss: 1.0497
# Epoch 37/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 176s 784ms/step - accuracy: 0.6185 - loss: 1.0135 - val_accuracy: 0.6088 - val_loss: 1.0474
# Epoch 38/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 178s 793ms/step - accuracy: 0.6249 - loss: 1.0056 - val_accuracy: 0.6016 - val_loss: 1.0502
# Epoch 39/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 178s 793ms/step - accuracy: 0.6277 - loss: 0.9917 - val_accuracy: 0.6071 - val_loss: 1.0441
# Epoch 40/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 177s 786ms/step - accuracy: 0.6269 - loss: 0.9956 - val_accuracy: 0.6056 - val_loss: 1.0440
# Epoch 41/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 176s 782ms/step - accuracy: 0.6293 - loss: 0.9956 - val_accuracy: 0.6042 - val_loss: 1.0470
# Epoch 42/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 176s 784ms/step - accuracy: 0.6387 - loss: 0.9716 - val_accuracy: 0.6101 - val_loss: 1.0378
# Epoch 43/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 173s 771ms/step - accuracy: 0.6329 - loss: 0.9870 - val_accuracy: 0.6133 - val_loss: 1.0335
# Epoch 44/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 164s 730ms/step - accuracy: 0.6377 - loss: 0.9673 - val_accuracy: 0.6088 - val_loss: 1.0375
# Epoch 45/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 165s 735ms/step - accuracy: 0.6418 - loss: 0.9623 - val_accuracy: 0.6085 - val_loss: 1.0434
# Epoch 46/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 753ms/step - accuracy: 0.6443 - loss: 0.9595 - val_accuracy: 0.6131 - val_loss: 1.0329
# Epoch 47/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 755ms/step - accuracy: 0.6456 - loss: 0.9516 - val_accuracy: 0.6115 - val_loss: 1.0422
# Epoch 48/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 761ms/step - accuracy: 0.6404 - loss: 0.9547 - val_accuracy: 0.6109 - val_loss: 1.0302
# Epoch 49/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 754ms/step - accuracy: 0.6442 - loss: 0.9497 - val_accuracy: 0.6138 - val_loss: 1.0355
# Epoch 50/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 750ms/step - accuracy: 0.6552 - loss: 0.9343 - val_accuracy: 0.6115 - val_loss: 1.0354
# Epoch 51/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 172s 765ms/step - accuracy: 0.6549 - loss: 0.9273 - val_accuracy: 0.6127 - val_loss: 1.0380
# Epoch 52/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 755ms/step - accuracy: 0.6489 - loss: 0.9306 - val_accuracy: 0.6184 - val_loss: 1.0280
# Epoch 53/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 752ms/step - accuracy: 0.6537 - loss: 0.9235 - val_accuracy: 0.6148 - val_loss: 1.0331
# Epoch 54/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 752ms/step - accuracy: 0.6602 - loss: 0.9082 - val_accuracy: 0.6144 - val_loss: 1.0373
# Epoch 55/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 750ms/step - accuracy: 0.6620 - loss: 0.8981 - val_accuracy: 0.6145 - val_loss: 1.0306
# Epoch 56/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 751ms/step - accuracy: 0.6626 - loss: 0.9058 - val_accuracy: 0.6155 - val_loss: 1.0323
# Epoch 57/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 753ms/step - accuracy: 0.6621 - loss: 0.9054 - val_accuracy: 0.6170 - val_loss: 1.0296
# Epoch 58/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 747ms/step - accuracy: 0.6695 - loss: 0.8998 - val_accuracy: 0.6170 - val_loss: 1.0282
# Epoch 59/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 746ms/step - accuracy: 0.6707 - loss: 0.8861 - val_accuracy: 0.6167 - val_loss: 1.0191
# Epoch 60/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 750ms/step - accuracy: 0.6676 - loss: 0.8910 - val_accuracy: 0.6108 - val_loss: 1.0336
# Epoch 61/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 746ms/step - accuracy: 0.6803 - loss: 0.8665 - val_accuracy: 0.6170 - val_loss: 1.0299
# Epoch 62/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 748ms/step - accuracy: 0.6805 - loss: 0.8676 - val_accuracy: 0.6237 - val_loss: 1.0283
# Epoch 63/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 748ms/step - accuracy: 0.6809 - loss: 0.8780 - val_accuracy: 0.6197 - val_loss: 1.0298
# Epoch 64/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 750ms/step - accuracy: 0.6800 - loss: 0.8769 - val_accuracy: 0.6227 - val_loss: 1.0278
# Epoch 65/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 747ms/step - accuracy: 0.6772 - loss: 0.8637 - val_accuracy: 0.6222 - val_loss: 1.0190
# Epoch 66/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 750ms/step - accuracy: 0.6844 - loss: 0.8506 - val_accuracy: 0.6215 - val_loss: 1.0231
# Epoch 67/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 162s 721ms/step - accuracy: 0.6850 - loss: 0.8651 - val_accuracy: 0.6209 - val_loss: 1.0233
# Epoch 68/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 166s 740ms/step - accuracy: 0.6908 - loss: 0.8462 - val_accuracy: 0.6187 - val_loss: 1.0381
# Epoch 69/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 745ms/step - accuracy: 0.6889 - loss: 0.8408 - val_accuracy: 0.6219 - val_loss: 1.0207
# Epoch 70/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 755ms/step - accuracy: 0.6939 - loss: 0.8377 - val_accuracy: 0.6186 - val_loss: 1.0231
# Epoch 71/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 746ms/step - accuracy: 0.6993 - loss: 0.8189 - val_accuracy: 0.6252 - val_loss: 1.0175
# Epoch 72/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 744ms/step - accuracy: 0.6928 - loss: 0.8313 - val_accuracy: 0.6234 - val_loss: 1.0205
# Epoch 73/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 744ms/step - accuracy: 0.6951 - loss: 0.8305 - val_accuracy: 0.6254 - val_loss: 1.0185
# Epoch 74/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 744ms/step - accuracy: 0.6993 - loss: 0.8229 - val_accuracy: 0.6269 - val_loss: 1.0217
# Epoch 75/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 743ms/step - accuracy: 0.6974 - loss: 0.8154 - val_accuracy: 0.6308 - val_loss: 1.0159
# Epoch 76/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 743ms/step - accuracy: 0.7064 - loss: 0.8017 - val_accuracy: 0.6318 - val_loss: 1.0217
# Epoch 77/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 743ms/step - accuracy: 0.7107 - loss: 0.8008 - val_accuracy: 0.6283 - val_loss: 1.0125
# Epoch 78/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 744ms/step - accuracy: 0.7005 - loss: 0.8128 - val_accuracy: 0.6300 - val_loss: 1.0318
# Epoch 79/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 748ms/step - accuracy: 0.7007 - loss: 0.8106 - val_accuracy: 0.6255 - val_loss: 1.0289
# Epoch 80/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 742ms/step - accuracy: 0.7074 - loss: 0.7916 - val_accuracy: 0.6276 - val_loss: 1.0247
# Epoch 81/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 743ms/step - accuracy: 0.7034 - loss: 0.7909 - val_accuracy: 0.6344 - val_loss: 1.0220
# Epoch 82/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 746ms/step - accuracy: 0.7208 - loss: 0.7708 - val_accuracy: 0.6291 - val_loss: 1.0157
# Epoch 83/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 743ms/step - accuracy: 0.7139 - loss: 0.7924 - val_accuracy: 0.6233 - val_loss: 1.0266
# Epoch 84/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 167s 740ms/step - accuracy: 0.7115 - loss: 0.7869 - val_accuracy: 0.6305 - val_loss: 1.0086
# Epoch 85/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 166s 738ms/step - accuracy: 0.7246 - loss: 0.7657 - val_accuracy: 0.6269 - val_loss: 1.0216
# Epoch 86/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 160s 713ms/step - accuracy: 0.7188 - loss: 0.7781 - val_accuracy: 0.6232 - val_loss: 1.0249
# Epoch 87/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 160s 712ms/step - accuracy: 0.7141 - loss: 0.7657 - val_accuracy: 0.6244 - val_loss: 1.0316
# Epoch 88/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 164s 727ms/step - accuracy: 0.7233 - loss: 0.7532 - val_accuracy: 0.6237 - val_loss: 1.0248
# Epoch 89/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 166s 738ms/step - accuracy: 0.7254 - loss: 0.7652 - val_accuracy: 0.6264 - val_loss: 1.0342
# Epoch 90/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 748ms/step - accuracy: 0.7249 - loss: 0.7605 - val_accuracy: 0.6305 - val_loss: 1.0152
# Epoch 91/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 759ms/step - accuracy: 0.7235 - loss: 0.7590 - val_accuracy: 0.6308 - val_loss: 1.0216
# Epoch 92/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 758ms/step - accuracy: 0.7290 - loss: 0.7423 - val_accuracy: 0.6325 - val_loss: 1.0339
# Epoch 93/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 172s 765ms/step - accuracy: 0.7299 - loss: 0.7449 - val_accuracy: 0.6275 - val_loss: 1.0207
# Epoch 94/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 173s 770ms/step - accuracy: 0.7308 - loss: 0.7439 - val_accuracy: 0.6257 - val_loss: 1.0319
# Epoch 95/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 172s 763ms/step - accuracy: 0.7293 - loss: 0.7299 - val_accuracy: 0.6264 - val_loss: 1.0204
# Epoch 96/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 172s 763ms/step - accuracy: 0.7351 - loss: 0.7335 - val_accuracy: 0.6326 - val_loss: 1.0143
# Epoch 97/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 762ms/step - accuracy: 0.7372 - loss: 0.7227 - val_accuracy: 0.6305 - val_loss: 1.0300
# Epoch 98/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 760ms/step - accuracy: 0.7323 - loss: 0.7359 - val_accuracy: 0.6232 - val_loss: 1.0218
# Epoch 99/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 758ms/step - accuracy: 0.7323 - loss: 0.7357 - val_accuracy: 0.6304 - val_loss: 1.0196
# Epoch 100/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 761ms/step - accuracy: 0.7410 - loss: 0.7102 - val_accuracy: 0.6271 - val_loss: 1.0286

# %%
model_json = model.to_json()

with open("Emomodel.json", 'w') as json_file:
    json_file.write(model_json)

model.save("Emomodel.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import model_from_json

# %%
json_file = open("Emomodel.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("Emomodel.h5")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image, color_mode='grayscale', target_size=(48,48))  # Ensure correct size
    feature = img_to_array(img)  # Convert image to numpy array
    feature = feature.reshape(1, 48, 48, 1)  # Reshape to match model input shape
    feature = feature / 255.0  # Normalize pixel values
    return feature

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'dataset/train/sad/Training_2913.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# model prediction is  sad

# %%
image = 'dataset/train/disgust/Training_680349.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# model prediction is  disgust

# %%
image = 'dataset/train/happy/Training_87867.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# model prediction is  happy

# %%
image = 'dataset/train/surprise/Training_797925.jpg'
print("original image is of surprise")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# model prediction is  surprise

# %%
import cv2
import numpy as np
from keras.models import load_model
from keras.preprocessing.image import img_to_array

# Load the pre-trained emotion detection model
model_path = 'Emomodel.h5'
classifier = load_model(model_path)

# Load the Haar cascade for face detection
haar_file = cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(haar_file)

# Define the emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Start webcam (use 0 for default camera, 1 for external camera)
cap = cv2.VideoCapture(0)

# Check if webcam opens correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    # Read frame from webcam
    ret, frame = cap.read()

    # Check if frame is read correctly
    if not ret:
        print("Error: Failed to capture image.")
        break  # Exit loop if no frame is captured

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the grayscale image
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

    for (x, y, w, h) in faces:
        # Extract the face region
        face = gray[y:y+h, x:x+w]

        # Resize the face to 48x48 pixels
        face = cv2.resize(face, (48, 48))
        
        # Normalize and expand dimensions for model prediction
        face = face.astype('float32') / 255.0
        face = np.expand_dims(face, axis=0)  # Shape should be (1, 48, 48, 1) for the model

        # Predict emotion using the classifier
        prediction = classifier.predict(face)
        label = emotion_labels[np.argmax(prediction)]

        # Draw a rectangle around the face and add the emotion label
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Display the frame with emotion label
    cv2.imshow('Emotion Detector', frame)

    # Exit the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break  # Ensure proper indentation here

# Release the webcam and close the window
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2025-04-02 22:09:03.776 Python[3845:73404] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
from sklearn.preprocessing import LabelEncoder
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from PIL import Image
from keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt

# %%
TRAIN_DR = "Dataset/train"
TEST_DR = "Dataset/test"

# %%
def create_dataframe(directory):
    image_paths = []
    labels = []
    for label_entry in os.scandir(directory):
        if label_entry.is_dir():
            label = label_entry.name
            for image_entry in os.scandir(label_entry.path):
                if image_entry.is_file():
                    image_paths.append(image_entry.path)
                    labels.append(label)
            print(label, "completed")
    return pd.DataFrame({"Image_Path": image_paths, "Label": labels})

# %%
# Create the DataFrame for training data
train = create_dataframe(TRAIN_DR)

# Display the first few rows of the DataFrame
print(train)
print(train['Image_Path'])
print(train['Label'].value_counts())
# Out:
# happy completed
# sad completed
# fear completed
# surprise completed
# neutral completed
# angry completed
# disgust completed
#                                         Image_Path    Label
# 0        Dataset/train/happy/Training_50449107.jpg    happy
# 1        Dataset/train/happy/Training_70433018.jpg    happy
# 2        Dataset/train/happy/Training_85610005.jpg    happy
# 3         Dataset/train/happy/Training_4460748.jpg    happy
# 4         Dataset/train/happy/Training_6312930.jpg    happy
# ...                                            ...      ...
# 28704  Dataset/train/disgust/Training_94788538.jpg  disgust
# 28705  Dataset/train/disgust/Training_81049148.jpg  disgust
# 28706  Dataset/train/disgust/Training_28365203.jpg  disgust
# 28707  Dataset/train/disgust/Training_39197750.jpg  disgust
# 28708  Dataset/train/disgust/Training_12525818.jpg  disgust
#
# [28709 rows x 2 columns]
# 0          Dataset/train/happy/Training_50449107.jpg
# 1          Dataset/train/happy/Training_70433018.jpg
# 2          Dataset/train/happy/Training_85610005.jpg
# 3           Dataset/train/happy/Training_4460748.jpg
# 4           Dataset/train/happy/Training_6312930.jpg
#                             ...
# 28704    Dataset/train/disgust/Training_94788538.jpg
# 28705    Dataset/train/disgust/Training_81049148.jpg
# 28706    Dataset/train/disgust/Training_28365203.jpg
# 28707    Dataset/train/disgust/Training_39197750.jpg
# 28708    Dataset/train/disgust/Training_12525818.jpg
# Name: Image_Path, Length: 28709, dtype: object
# Label
# happy       7215
# neutral     4965
# sad         4830
# fear        4097
# angry       3995
# surprise    3171
# disgust      436
# Name: count, dtype: int64

# %%
# Create the DataFrame for test data
test = create_dataframe(TEST_DR)

# Display the first few rows of the DataFrame
print(test)
print(test['Image_Path'])
print(test['Label'].value_counts())
# Out:
# happy completed
# sad completed
# fear completed
# surprise completed
# neutral completed
# angry completed
# disgust completed
#                                          Image_Path    Label
# 0       Dataset/test/happy/PrivateTest_45699463.jpg    happy
# 1       Dataset/test/happy/PrivateTest_61855708.jpg    happy
# 2        Dataset/test/happy/PublicTest_53681781.jpg    happy
# 3       Dataset/test/happy/PrivateTest_52109800.jpg    happy
# 4        Dataset/test/happy/PublicTest_41104919.jpg    happy
# ...                                             ...      ...
# 7173  Dataset/test/disgust/PrivateTest_79683471.jpg  disgust
# 7174  Dataset/test/disgust/PrivateTest_34013087.jpg  disgust
# 7175   Dataset/test/disgust/PublicTest_67559665.jpg  disgust
# 7176  Dataset/test/disgust/PrivateTest_89077668.jpg  disgust
# 7177  Dataset/test/disgust/PrivateTest_53395751.jpg  disgust
#
# [7178 rows x 2 columns]
# 0         Dataset/test/happy/PrivateTest_45699463.jpg
# 1         Dataset/test/happy/PrivateTest_61855708.jpg
# 2          Dataset/test/happy/PublicTest_53681781.jpg
# 3         Dataset/test/happy/PrivateTest_52109800.jpg
# 4          Dataset/test/happy/PublicTest_41104919.jpg
#                             ...
# 7173    Dataset/test/disgust/PrivateTest_79683471.jpg
# 7174    Dataset/test/disgust/PrivateTest_34013087.jpg
# 7175     Dataset/test/disgust/PublicTest_67559665.jpg
# 7176    Dataset/test/disgust/PrivateTest_89077668.jpg
# 7177    Dataset/test/disgust/PrivateTest_53395751.jpg
# Name: Image_Path, Length: 7178, dtype: object
# Label
# happy       1774
# sad         1247
# neutral     1233
# fear        1024
# angry        958
# surprise     831
# disgust      111
# Name: count, dtype: int64

# %%
def extract_features(images, target_size=(48, 48)):
    features = []
    for image in tqdm(images):
        img = load_img(image, target_size=target_size, color_mode='grayscale')
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features), target_size[0], target_size[1], 1)
    return features

# %%
train_features = extract_features(train['Image_Path'])
# Out:
# 100%|███████████████████████████████████| 28709/28709 [00:04<00:00, 5816.01it/s]

# %%
test_features = extract_features(test['Image_Path'])
# Out:
# 100%|█████████████████████████████████████| 7178/7178 [00:01<00:00, 6111.92it/s]

# %%
x_train = train_features/250.0  # Scale pixle values to [0, 1]
x_test = test_features/250.0

# %%
# Assuming train is your DataFrame containing image paths and labels
le = LabelEncoder()
le.fit(train['Label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['Label'])
y_test = le.transform(test['Label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
model = Sequential()
# convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer
model.add(Dense(7, activation='softmax'))
# Out:
# /Users/yaswanthkommineni/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x= x_train,y = y_train, batch_size = 128, epochs = 100, validation_data = (x_test,y_test))
# Out:
# Epoch 1/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 135s 596ms/step - accuracy: 0.2366 - loss: 1.8380 - val_accuracy: 0.2471 - val_loss: 1.8141
# Epoch 2/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 142s 629ms/step - accuracy: 0.2499 - loss: 1.8125 - val_accuracy: 0.2563 - val_loss: 1.7791
# Epoch 3/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 149s 662ms/step - accuracy: 0.2694 - loss: 1.7595 - val_accuracy: 0.3270 - val_loss: 1.6747
# Epoch 4/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 150s 667ms/step - accuracy: 0.3288 - loss: 1.6703 - val_accuracy: 0.4023 - val_loss: 1.5262
# Epoch 5/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 151s 673ms/step - accuracy: 0.3886 - loss: 1.5679 - val_accuracy: 0.4419 - val_loss: 1.4476
# Epoch 6/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 156s 693ms/step - accuracy: 0.4207 - loss: 1.4881 - val_accuracy: 0.4770 - val_loss: 1.3706
# Epoch 7/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 157s 698ms/step - accuracy: 0.4427 - loss: 1.4373 - val_accuracy: 0.4974 - val_loss: 1.3112
# Epoch 8/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 702ms/step - accuracy: 0.4639 - loss: 1.3953 - val_accuracy: 0.5022 - val_loss: 1.2889
# Epoch 9/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 159s 708ms/step - accuracy: 0.4732 - loss: 1.3662 - val_accuracy: 0.5060 - val_loss: 1.2699
# Epoch 10/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 161s 716ms/step - accuracy: 0.4866 - loss: 1.3355 - val_accuracy: 0.5340 - val_loss: 1.2208
# Epoch 11/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 160s 713ms/step - accuracy: 0.4983 - loss: 1.3192 - val_accuracy: 0.5375 - val_loss: 1.2035
# Epoch 12/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 160s 713ms/step - accuracy: 0.5061 - loss: 1.3011 - val_accuracy: 0.5426 - val_loss: 1.1936
# Epoch 13/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 161s 717ms/step - accuracy: 0.5134 - loss: 1.2830 - val_accuracy: 0.5485 - val_loss: 1.1801
# Epoch 14/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 164s 730ms/step - accuracy: 0.5186 - loss: 1.2597 - val_accuracy: 0.5532 - val_loss: 1.1625
# Epoch 15/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 174s 774ms/step - accuracy: 0.5250 - loss: 1.2532 - val_accuracy: 0.5561 - val_loss: 1.1455
# Epoch 16/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.5232 - loss: 1.2453 - val_accuracy: 0.5580 - val_loss: 1.1661
# Epoch 17/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 214s 950ms/step - accuracy: 0.5361 - loss: 1.2268 - val_accuracy: 0.5584 - val_loss: 1.1461
# Epoch 18/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 164s 729ms/step - accuracy: 0.5411 - loss: 1.2136 - val_accuracy: 0.5642 - val_loss: 1.1396
# Epoch 19/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 752ms/step - accuracy: 0.5414 - loss: 1.2108 - val_accuracy: 0.5688 - val_loss: 1.1245
# Epoch 20/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 172s 764ms/step - accuracy: 0.5475 - loss: 1.1950 - val_accuracy: 0.5605 - val_loss: 1.1329
# Epoch 21/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 762ms/step - accuracy: 0.5529 - loss: 1.1813 - val_accuracy: 0.5662 - val_loss: 1.1300
# Epoch 22/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 745ms/step - accuracy: 0.5552 - loss: 1.1713 - val_accuracy: 0.5723 - val_loss: 1.1130
# Epoch 23/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 760ms/step - accuracy: 0.5568 - loss: 1.1747 - val_accuracy: 0.5830 - val_loss: 1.0907
# Epoch 24/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 174s 773ms/step - accuracy: 0.5596 - loss: 1.1666 - val_accuracy: 0.5797 - val_loss: 1.0999
# Epoch 25/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 166s 739ms/step - accuracy: 0.5664 - loss: 1.1479 - val_accuracy: 0.5798 - val_loss: 1.0937
# Epoch 26/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 166s 738ms/step - accuracy: 0.5665 - loss: 1.1403 - val_accuracy: 0.5867 - val_loss: 1.0848
# Epoch 27/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 166s 740ms/step - accuracy: 0.5738 - loss: 1.1300 - val_accuracy: 0.5823 - val_loss: 1.0839
# Epoch 28/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 756ms/step - accuracy: 0.5791 - loss: 1.1269 - val_accuracy: 0.5874 - val_loss: 1.0779
# Epoch 29/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 175s 777ms/step - accuracy: 0.5746 - loss: 1.1217 - val_accuracy: 0.5865 - val_loss: 1.0750
# Epoch 30/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 176s 784ms/step - accuracy: 0.5770 - loss: 1.1165 - val_accuracy: 0.5925 - val_loss: 1.0666
# Epoch 31/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 176s 782ms/step - accuracy: 0.5770 - loss: 1.1028 - val_accuracy: 0.5921 - val_loss: 1.0738
# Epoch 32/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 177s 785ms/step - accuracy: 0.5841 - loss: 1.1052 - val_accuracy: 0.5907 - val_loss: 1.0763
# Epoch 33/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 173s 770ms/step - accuracy: 0.5796 - loss: 1.1091 - val_accuracy: 0.5931 - val_loss: 1.0562
# Epoch 34/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 747ms/step - accuracy: 0.5913 - loss: 1.0855 - val_accuracy: 0.5908 - val_loss: 1.0685
# Epoch 35/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 758ms/step - accuracy: 0.5864 - loss: 1.0864 - val_accuracy: 0.6050 - val_loss: 1.0480
# Epoch 36/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 762ms/step - accuracy: 0.5922 - loss: 1.0725 - val_accuracy: 0.5953 - val_loss: 1.0595
# Epoch 37/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 171s 761ms/step - accuracy: 0.5958 - loss: 1.0674 - val_accuracy: 0.6041 - val_loss: 1.0527
# Epoch 38/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 180s 800ms/step - accuracy: 0.5963 - loss: 1.0631 - val_accuracy: 0.5981 - val_loss: 1.0601
# Epoch 39/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - accuracy: 0.6001 - loss: 1.0576 - val_accuracy: 0.6018 - val_loss: 1.0488
# Epoch 40/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 173s 769ms/step - accuracy: 0.6062 - loss: 1.0524 - val_accuracy: 0.6030 - val_loss: 1.0461
# Epoch 41/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 174s 776ms/step - accuracy: 0.6073 - loss: 1.0452 - val_accuracy: 0.6091 - val_loss: 1.0373
# Epoch 42/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 174s 775ms/step - accuracy: 0.6075 - loss: 1.0437 - val_accuracy: 0.6088 - val_loss: 1.0369
# Epoch 43/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 175s 776ms/step - accuracy: 0.6085 - loss: 1.0483 - val_accuracy: 0.6039 - val_loss: 1.0466
# Epoch 44/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 174s 776ms/step - accuracy: 0.6170 - loss: 1.0214 - val_accuracy: 0.6057 - val_loss: 1.0327
# Epoch 45/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 176s 783ms/step - accuracy: 0.6131 - loss: 1.0337 - val_accuracy: 0.6050 - val_loss: 1.0416
# Epoch 46/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 176s 782ms/step - accuracy: 0.6105 - loss: 1.0251 - val_accuracy: 0.6066 - val_loss: 1.0306
# Epoch 47/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 177s 785ms/step - accuracy: 0.6154 - loss: 1.0230 - val_accuracy: 0.6050 - val_loss: 1.0524
# Epoch 48/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 176s 784ms/step - accuracy: 0.6191 - loss: 1.0213 - val_accuracy: 0.6099 - val_loss: 1.0389
# Epoch 49/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 176s 782ms/step - accuracy: 0.6286 - loss: 1.0062 - val_accuracy: 0.6140 - val_loss: 1.0438
# Epoch 50/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 176s 781ms/step - accuracy: 0.6218 - loss: 1.0060 - val_accuracy: 0.6081 - val_loss: 1.0340
# Epoch 51/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 175s 780ms/step - accuracy: 0.6231 - loss: 1.0013 - val_accuracy: 0.6142 - val_loss: 1.0331
# Epoch 52/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 175s 778ms/step - accuracy: 0.6250 - loss: 0.9942 - val_accuracy: 0.6108 - val_loss: 1.0308
# Epoch 53/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 174s 773ms/step - accuracy: 0.6341 - loss: 0.9818 - val_accuracy: 0.6123 - val_loss: 1.0264
# Epoch 54/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 160s 710ms/step - accuracy: 0.6306 - loss: 0.9886 - val_accuracy: 0.6077 - val_loss: 1.0316
# Epoch 55/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 159s 707ms/step - accuracy: 0.6443 - loss: 0.9643 - val_accuracy: 0.6081 - val_loss: 1.0347
# Epoch 56/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 703ms/step - accuracy: 0.6395 - loss: 0.9664 - val_accuracy: 0.6108 - val_loss: 1.0291
# Epoch 57/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 702ms/step - accuracy: 0.6449 - loss: 0.9490 - val_accuracy: 0.6115 - val_loss: 1.0352
# Epoch 58/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 157s 697ms/step - accuracy: 0.6479 - loss: 0.9556 - val_accuracy: 0.6183 - val_loss: 1.0255
# Epoch 59/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 156s 694ms/step - accuracy: 0.6487 - loss: 0.9491 - val_accuracy: 0.6152 - val_loss: 1.0230
# Epoch 60/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 156s 695ms/step - accuracy: 0.6544 - loss: 0.9367 - val_accuracy: 0.6183 - val_loss: 1.0271
# Epoch 61/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 157s 700ms/step - accuracy: 0.6508 - loss: 0.9399 - val_accuracy: 0.6216 - val_loss: 1.0202
# Epoch 62/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 703ms/step - accuracy: 0.6539 - loss: 0.9408 - val_accuracy: 0.6135 - val_loss: 1.0277
# Epoch 63/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 704ms/step - accuracy: 0.6471 - loss: 0.9388 - val_accuracy: 0.6142 - val_loss: 1.0311
# Epoch 64/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 160s 711ms/step - accuracy: 0.6502 - loss: 0.9382 - val_accuracy: 0.6128 - val_loss: 1.0319
# Epoch 65/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 157s 696ms/step - accuracy: 0.6534 - loss: 0.9330 - val_accuracy: 0.6108 - val_loss: 1.0303
# Epoch 66/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 157s 697ms/step - accuracy: 0.6594 - loss: 0.9241 - val_accuracy: 0.6156 - val_loss: 1.0318
# Epoch 67/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 156s 694ms/step - accuracy: 0.6636 - loss: 0.9093 - val_accuracy: 0.6257 - val_loss: 1.0120
# Epoch 68/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 155s 691ms/step - accuracy: 0.6616 - loss: 0.9155 - val_accuracy: 0.6188 - val_loss: 1.0184
# Epoch 69/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 155s 690ms/step - accuracy: 0.6629 - loss: 0.9065 - val_accuracy: 0.6209 - val_loss: 1.0113
# Epoch 70/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 155s 690ms/step - accuracy: 0.6640 - loss: 0.9095 - val_accuracy: 0.6237 - val_loss: 1.0249
# Epoch 71/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 155s 688ms/step - accuracy: 0.6693 - loss: 0.8936 - val_accuracy: 0.6234 - val_loss: 1.0161
# Epoch 72/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 154s 686ms/step - accuracy: 0.6711 - loss: 0.8960 - val_accuracy: 0.6248 - val_loss: 1.0181
# Epoch 73/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 155s 688ms/step - accuracy: 0.6637 - loss: 0.9120 - val_accuracy: 0.6216 - val_loss: 1.0135
# Epoch 74/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 154s 684ms/step - accuracy: 0.6654 - loss: 0.9065 - val_accuracy: 0.6223 - val_loss: 1.0151
# Epoch 75/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 154s 683ms/step - accuracy: 0.6775 - loss: 0.8899 - val_accuracy: 0.6251 - val_loss: 1.0227
# Epoch 76/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 154s 684ms/step - accuracy: 0.6692 - loss: 0.8917 - val_accuracy: 0.6259 - val_loss: 1.0133
# Epoch 77/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 154s 687ms/step - accuracy: 0.6743 - loss: 0.8803 - val_accuracy: 0.6186 - val_loss: 1.0179
# Epoch 78/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 161s 715ms/step - accuracy: 0.6852 - loss: 0.8543 - val_accuracy: 0.6165 - val_loss: 1.0275
# Epoch 79/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 752ms/step - accuracy: 0.6846 - loss: 0.8662 - val_accuracy: 0.6269 - val_loss: 1.0114
# Epoch 80/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 205s 911ms/step - accuracy: 0.6817 - loss: 0.8649 - val_accuracy: 0.6308 - val_loss: 1.0127
# Epoch 81/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 197s 877ms/step - accuracy: 0.6822 - loss: 0.8712 - val_accuracy: 0.6290 - val_loss: 1.0141
# Epoch 82/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 206s 915ms/step - accuracy: 0.6846 - loss: 0.8494 - val_accuracy: 0.6262 - val_loss: 1.0167
# Epoch 83/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 203s 901ms/step - accuracy: 0.6857 - loss: 0.8564 - val_accuracy: 0.6286 - val_loss: 1.0074
# Epoch 84/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 196s 872ms/step - accuracy: 0.6864 - loss: 0.8533 - val_accuracy: 0.6315 - val_loss: 1.0105
# Epoch 85/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 199s 886ms/step - accuracy: 0.6934 - loss: 0.8310 - val_accuracy: 0.6244 - val_loss: 1.0168
# Epoch 86/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 199s 884ms/step - accuracy: 0.6941 - loss: 0.8446 - val_accuracy: 0.6284 - val_loss: 1.0096
# Epoch 87/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 224s 996ms/step - accuracy: 0.6927 - loss: 0.8402 - val_accuracy: 0.6258 - val_loss: 1.0141
# Epoch 88/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 202s 899ms/step - accuracy: 0.6968 - loss: 0.8281 - val_accuracy: 0.6319 - val_loss: 1.0063
# Epoch 89/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 166s 740ms/step - accuracy: 0.6971 - loss: 0.8235 - val_accuracy: 0.6303 - val_loss: 1.0084
# Epoch 90/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 751ms/step - accuracy: 0.6925 - loss: 0.8269 - val_accuracy: 0.6307 - val_loss: 1.0139
# Epoch 91/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 166s 739ms/step - accuracy: 0.6933 - loss: 0.8316 - val_accuracy: 0.6303 - val_loss: 1.0139
# Epoch 92/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 168s 747ms/step - accuracy: 0.6924 - loss: 0.8296 - val_accuracy: 0.6304 - val_loss: 1.0130
# Epoch 93/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 751ms/step - accuracy: 0.7007 - loss: 0.8247 - val_accuracy: 0.6266 - val_loss: 1.0120
# Epoch 94/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 751ms/step - accuracy: 0.7026 - loss: 0.8140 - val_accuracy: 0.6247 - val_loss: 1.0234
# Epoch 95/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 756ms/step - accuracy: 0.6976 - loss: 0.8157 - val_accuracy: 0.6257 - val_loss: 1.0155
# Epoch 96/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 758ms/step - accuracy: 0.7044 - loss: 0.8054 - val_accuracy: 0.6317 - val_loss: 1.0171
# Epoch 97/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 172s 763ms/step - accuracy: 0.7055 - loss: 0.8047 - val_accuracy: 0.6273 - val_loss: 1.0166
# Epoch 98/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 169s 753ms/step - accuracy: 0.7069 - loss: 0.7993 - val_accuracy: 0.6319 - val_loss: 1.0198
# Epoch 99/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 170s 758ms/step - accuracy: 0.7109 - loss: 0.7982 - val_accuracy: 0.6321 - val_loss: 1.0163
# Epoch 100/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 164s 727ms/step - accuracy: 0.7133 - loss: 0.7913 - val_accuracy: 0.6322 - val_loss: 1.0185

# %%
model_json = model.to_json()

with open("Emotiondetector.json", 'w') as json_file:
    json_file.write(model_json)

model.save("Emotiondetector.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import model_from_json
# Out:
# /Users/yaswanthkommineni/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Matplotlib is building the font cache; this may take a moment.

# %%
json_file = open("Emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("Emotiondetector.h5")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,grayscale =  True )
    feature = np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
def ef(image):
    img = load_img(image, color_mode='grayscale', target_size=(48,48))  # Ensure correct size
    feature = img_to_array(img)  # Convert image to numpy array
    feature = feature.reshape(1, 48, 48, 1)  # Reshape to match model input shape
    feature = feature / 255.0  # Normalize pixel values
    return feature

# Example image path
image_path = 'Dataset/train/sad/Training_99823693.jpg'
print("Original image is of 'sad'")

# Preprocess the image
img = preprocess_image(image_path)

# Make predictions using the model
pred = model.predict(img)

# Get the predicted label
pred_label = label[pred.argmax()]

print("Model prediction is:", pred_label)
# Out:
# Original image is of 'sad'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Model prediction is: sad

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'Dataset/train/sad/Training_99823693.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# model prediction is  sad

# %%
image = 'Dataset/train/fear/Training_99984859.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# model prediction is  fear

# %%
image = 'Dataset/train/disgust/Training_8937293.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# model prediction is  disgust

# %%
image = 'Dataset/train/happy/Training_99973350.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# model prediction is  happy

# %%
image = 'Dataset/train/surprise/Training_99924420.jpg'
print("original image is of surprise")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# model prediction is  surprise

# %%
import cv2
import numpy as np
from keras.models import load_model
from keras.preprocessing.image import img_to_array

# Load the pre-trained emotion detection model
model_path = 'Emotiondetector.h5'
classifier = load_model(model_path)

# Load the Haar cascade for face detection
haar_file = cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(haar_file)

# Define the emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Start webcam (use 0 for default camera, 1 for external camera)
cap = cv2.VideoCapture(0)

# Check if webcam opens correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    # Read frame from webcam
    ret, frame = cap.read()

    # Check if frame is read correctly
    if not ret:
        print("Error: Failed to capture image.")
        break  # Exit loop if no frame is captured

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the grayscale image
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

    for (x, y, w, h) in faces:
        # Extract the face region
        face = gray[y:y+h, x:x+w]

        # Resize the face to 48x48 pixels
        face = cv2.resize(face, (48, 48))
        
        # Normalize and expand dimensions for model prediction
        face = face.astype('float32') / 255.0
        face = np.expand_dims(face, axis=0)  # Shape should be (1, 48, 48, 1) for the model

        # Predict emotion using the classifier
        prediction = classifier.predict(face)
        label = emotion_labels[np.argmax(prediction)]

        # Draw a rectangle around the face and add the emotion label
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Display the frame with emotion label
    cv2.imshow('Emotion Detector', frame)

    # Exit the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close the window
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

for _ in range(10):  # Capture multiple frames to ensure a valid frame
    ret, frame = cap.read()
    if ret:
        break

cap.release()

if not ret:
    print("Error: Failed to capture image.")
    exit()

cv2.imshow('Captured Frame', frame)
cv2.waitKey(0)  # Wait for key press
cv2.destroyAllWindows()
